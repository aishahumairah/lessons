# %% [markdown]
# # Engineering Growth Plan
#
# **Data Engineering Course — Week 1**
#
# ---
#
# This is a living document. Write it honestly — not aspirationally.
#
# You will return to it twice:
# - **Week 6** — midpoint check-in: what's changed, what's harder than expected, what needs adjusting
# - **Week 12** — graduation: read your Week 1 self and measure the distance
#
# **How to fill this in:** Double-click any cell with *italic placeholder text* to edit it. Press **Shift+Enter** to save and move on.
#
# **Time to complete:** 20–30 minutes. Don't rush it.
#
# ---
#
# > Commit this file to GitHub after completing it:
# > ```bash
# > git add week1/activities/engineering_growth_plan.ipynb
# > git commit -m "Add Week 1 engineering growth plan"
# > git push
# > ```

# %% [markdown]
# ---
#
# ## Section 1: About Me
#
# *Complete as of Week 1 start date.*
#
# **Name:**

# %% [markdown]
# *Your name*

# %% [markdown]
# **Current role / background:**
# *(What do you do now? What's your professional background before this course?)*

# %% [markdown]
# *e.g. "I work as a junior analyst at a retail company. My background is Excel and basic SQL. I've never built a pipeline or used any cloud tools."*

# %% [markdown]
# **How I heard about / why I chose this program:**

# %% [markdown]
# *Your answer*

# %% [markdown]
# ---
#
# ## Section 2: My "Why"
#
# This is the most important section. A clear "why" keeps you going at Week 7 when things are hard.
#
# **Why data engineering specifically — not analytics, not development, not something else?**
#
# *(Write 2–4 sentences. Be honest. "I heard it pays well" is a valid partial answer — but dig deeper. What about the work itself appeals to you?)*

# %% [markdown]
# *e.g. "I want to be the person who makes sure the data is right before it reaches the analyst. I've been on the receiving end of broken data at work and it was frustrating not to be able to fix it. I want to be someone who can fix it."*

# %% [markdown]
# **What will be different in your life or career if you successfully complete this program?**

# %% [markdown]
# *Your answer*

# %% [markdown]
# ---
#
# ## Section 3: Skills Self-Assessment
#
# Rate yourself honestly on each skill **right now — Week 1, before most lessons**.
#
# | Skill | 1 Never heard of it | 2 Heard of it | 3 Basic idea | 4 Some hands-on experience | 5 Confident |
# |-------|:-------------------:|:-------------:|:------------:|:--------------------------:|:-----------:|
# | SQL (SELECT, WHERE, joins) | | | | | |
# | Python (scripting, functions) | | | | | |
# | PostgreSQL / relational databases | | | | | |
# | Git / GitHub | | | | | |
# | Command line / terminal | | | | | |
# | Cloud platforms (AWS, GCP, Azure) | | | | | |
# | Data modeling (tables, schemas) | | | | | |
# | ETL / pipeline thinking | | | | | |
# | Docker / containerization | | | | | |
# | Data warehousing concepts | | | | | |
#
# **In the cells below, mark your rating with an X. Example: if SQL is a 3, put X in the "3 Basic idea" column.**
#
# *(Or simply re-type the table above with your X marks in the right columns.)*
#
# **The two skills I'm most confident in right now:**

# %% [markdown]
# 1. *Skill + why you feel confident*
#
# 2. *Skill + why you feel confident*

# %% [markdown]
# **The two skills I'm most anxious about:**

# %% [markdown]
# 1. *Skill + what specifically worries you*
#
# 2. *Skill + what specifically worries you*

# %% [markdown]
# ---
#
# ## Section 4: My Week 12 Vision
#
# Answer these as specifically as possible. Vague goals produce vague results.
#
# **By the end of Week 12, I want to be able to say:**
#
# *(Finish this sentence with 3–5 concrete statements. Examples: "I can build and schedule a pipeline that loads raw data into a warehouse." / "I understand what dbt does well enough to explain it in an interview.")*

# %% [markdown]
# 1. *Statement 1*
#
# 2. *Statement 2*
#
# 3. *Statement 3*
#
# 4. *Statement 4 (optional)*
#
# 5. *Statement 5 (optional)*

# %% [markdown]
# **The project or portfolio piece I want to have built by Week 12:**
#
# *(What problem does it solve? What data does it move? What tools does it use? Even a rough idea is fine — it will evolve.)*

# %% [markdown]
# *e.g. "A pipeline that pulls public weather data from an API every hour, loads it into a PostgreSQL database, transforms it with dbt, and produces a summary table showing average temperature by city per week."*

# %% [markdown]
# ---
#
# ## Section 5: Tools I Want to Master
#
# From the course curriculum, pick **3–5 tools** you most want to become genuinely confident with — not just "have seen."
#
# | Tool | Why this one matters to my goals |
# |------|----------------------------------|
# | *e.g. dbt* | *I want to write SQL transformations that are tested and documented like real engineering work* |
# | | |
# | | |
# | | |
# | | |

# %% [markdown]
# ---
#
# ## Section 6: My Weekly Commitment
#
# Be realistic. Overcommitting in Week 1 and burning out in Week 4 is the most common failure mode.
#
# **Hours per week I can realistically commit to this program:**

# %% [markdown]
# *e.g. "10 hours — weekday evenings (1.5h Mon/Wed/Fri) + Sunday morning (4h)"*

# %% [markdown]
# **My typical study schedule:**
#
# | Day | Time block | Hours |
# |-----|-----------|-------|
# | Monday | | |
# | Tuesday | | |
# | Wednesday | | |
# | Thursday | | |
# | Friday | | |
# | Saturday | | |
# | Sunday | | |
# | **Total** | | |

# %% [markdown]
# **If I fall behind by more than one week, my plan is:**

# %% [markdown]
# *e.g. "I'll flag it immediately to my instructor rather than quietly hoping to catch up. I'll block a Saturday morning to do a focused catch-up session. I won't skip the exercises to save time — those are the most valuable part."*

# %% [markdown]
# ---
#
# ## Section 7: Anticipated Obstacles
#
# Think about what will realistically make this hard. Write it down now so you have a plan before it happens.
#
# | Obstacle | How likely? (High / Med / Low) | My plan if it happens |
# |----------|-------------------------------|----------------------|
# | *e.g. Work gets busy and I miss a week* | *High* | *I'll do Sunday catch-up sessions and skip optional reading that week* |
# | | | |
# | | | |
# | | | |
#
# **The one thing most likely to cause me to quit or disengage:**

# %% [markdown]
# *Be honest. It might be imposter syndrome, a specific topic you dread, a scheduling conflict, or something personal.*

# %% [markdown]
# **My plan for when that happens:**

# %% [markdown]
# *Your specific plan — not "I'll try harder" but a concrete action.*

# %% [markdown]
# ---
#
# ## Section 8: How I Learn Best
#
# **My strongest learning style** *(reading, watching, doing, teaching, or a mix):*

# %% [markdown]
# *Your answer*

# %% [markdown]
# **When I'm stuck on something technical, my default approach is:**

# %% [markdown]
# *e.g. "I read the error message, Google it, try the first Stack Overflow answer, and if that doesn't work I ask."*

# %% [markdown]
# **After this program, I want my approach to getting unstuck to be:**

# %% [markdown]
# *e.g. "Read the error message fully. Understand what it's actually saying. Reproduce the problem in isolation. Google the specific error. Try for 20–30 minutes before asking. When I ask, describe what I tried."*

# %% [markdown]
# ---
#
# ## Section 9: Accountability
#
# **My accountability partner in this program** *(name of a classmate, colleague, or friend):*

# %% [markdown]
# *Name*

# %% [markdown]
# **What I've asked them to do:**

# %% [markdown]
# *e.g. "Check in with me every Friday via WhatsApp. If I haven't pushed a commit that week, call me out."*

# %% [markdown]
# **How I'll share my progress publicly** *(GitHub commits, a LinkedIn post every 2 weeks, a study group, etc.):*

# %% [markdown]
# *Your answer*

# %% [markdown]
# ---
#
# ## My Commitment
#
# Read this aloud before signing.
#
# > *I understand that this program will be challenging. I commit to doing the work even when it's frustrating, to asking for help before I fall too far behind, and to treating my classmates' and instructor's time with respect. I will measure my success not by whether everything is easy, but by whether I kept going when it was hard.*
#
# **Name:**

# %% [markdown]
# *Your name*

# %% [markdown]
# **Date:**

# %% [markdown]
# *Today's date*

# %% [markdown]
# ---
#
# ## Return Schedule
#
# | When | What to do |
# |------|------------|
# | **Week 6** | Re-read Sections 3 and 4. Update the skills table with your current ratings. Write a paragraph: what's harder than you expected, what's easier, and what you'd tell your Week 1 self. |
# | **Week 12** | Re-read the whole document. Answer: did you hit your Week 12 vision? Which tools did you actually master? What did the obstacles end up being? What are you proud of? |
#
# > Commit your Week 6 and Week 12 updates to the same file so you have a record of all three versions in your Git history.

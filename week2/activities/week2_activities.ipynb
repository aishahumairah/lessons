# %% [markdown]
# # Week 2 Activities — SQL Thinking
#
# **Week 2 · Data Engineering Course**
#
# ---
#
# This notebook covers the non-technical work for Week 2:
#
# 1. **Discussion** — How do you break a business question into SQL?
# 2. **Project Review** — Verify your Week 2 technical progress
# 3. **Reading Club** — *Things I Wished More Developers Knew About Databases*
# 4. **5-Minute Summary** — Your reactions to the reading
# 5. **Engineering Growth Plan** — Week 2 check-in
#
# **How to use this notebook:** Double-click cells with *italic placeholder text* to edit. Press **Shift+Enter** to save.

# %% [markdown]
# ---
#
# ## Part 1: Discussion
#
# ---
#
# ### Discussion 1: How Do You Break a Business Question into SQL?
#
# **Opening question:** A manager asks you: 'Who are our most valuable customers?' What is your first step before writing a single line of SQL?
#
# ---
#
# **Discussion prompts:**
#
# 1. 'Most valuable' could mean total spend, most orders, most recent activity, or highest average order. How do you decide which interpretation is correct? Who do you ask?
#
# 2. Walk through how you would mentally decompose this question into steps:
#    - Which tables do I need?
#    - How are they connected?
#    - What filter applies (all orders? completed only?)?
#    - What output columns does the answer need?
#
# 3. In Week 2 you learned JOINs, GROUP BY, and window functions. For this question, which tool would you reach for first — and why?
#
# 4. What is the difference between a query that answers the exact question asked and a query that *looks* like it answers the question but has a subtle flaw (wrong JOIN type, missing filter, wrong GROUP BY column)? How do you catch that?
#
# ---
#
# **Your notes from the discussion:**

# %% [markdown]
# *Double-click here and type your notes from Discussion 1.*

# %% [markdown]
# ### Discussion 2: Normalisation vs Convenience
#
# **Opening question:** Have you ever worked with a spreadsheet or system where the same piece of information was stored in multiple places? What went wrong when it got out of sync?
#
# ---
#
# **Discussion prompts:**
#
# 1. The retail database stores `customer_city` in the `customers` table, not in each order. Why? What would break if city were stored in `orders` instead?
#
# 2. Normalisation reduces redundancy but increases the number of JOINs your queries need. Is that always worth it? When might you intentionally denormalise data?
#
# 3. A team stores a customer name as `first_name` and `last_name` in separate columns. Another team stores it as `full_name` in one column. What are the trade-offs of each approach?
#
# 4. You discover the `orders` table has a `customer_city` column that is sometimes different from the value in `customers.city`. Which is the source of truth? How do you decide?
#
# ---
#
# **Your notes from the discussion:**

# %% [markdown]
# *Double-click here and type your notes from Discussion 2.*

# %% [markdown]
# ### Discussion 3: Reading Query Results Critically
#
# **Opening question:** A colleague runs a query, shows you the output, and says 'Revenue is up 40% this quarter.' What questions do you ask before trusting that number?
#
# ---
#
# **Discussion prompts:**
#
# 1. What are the three most common reasons a revenue query would return an incorrect number — not due to bad data, but due to a flaw in the query itself?
#
# 2. In Week 2, you learned that `LEFT JOIN` returns NULLs where there is no match. What happens to `SUM()` when one of the values being summed is NULL? Is this a problem?
#
# 3. A query returns 200 rows when you expect 50. List three possible causes. Which JOIN pattern most commonly causes row duplication?
#
# 4. You run the same business question two different ways (different SQL) and get different answers. How do you figure out which one is right?
#
# ---
#
# **Your notes from the discussion:**

# %% [markdown]
# *Double-click here and type your notes from Discussion 3.*

# %% [markdown]
# ---
#
# ## Part 2: Project Review
#
# Before moving to Week 3, confirm your Week 2 technical work is complete. Mark each item **Done ✓**, **Partial ⚠**, or **Not started ✗**.
#
# ---
#
# ### Lab 2: Retail Database
#
# | Item | Status | Notes |
# |------|--------|-------|
# | All 5 tables created (customers, salespeople, products, orders, order_items) | | |
# | All 5 CSV files loaded — row counts match (20, 5, 15, 50, 81) | | |
# | Foreign key constraints verified (no orphan rows) | | |
# | Indexes created on foreign key columns | | |
# | Multi-table JOIN query ran successfully in pgAdmin | | |
#
# ---
#
# ### SQL Exercises
#
# | Section | Status | Notes |
# |---------|--------|-------|
# | Section 1: INNER JOIN (1.1–1.5) | | |
# | Section 2: LEFT JOIN (2.1–2.4) | | |
# | Section 3: Aggregations (3.1–3.6) | | |
# | Section 4: CASE WHEN (4.1–4.4) | | |
# | Section 5: Subqueries (5.1–5.4) | | |
# | Section 6: CTEs (6.1–6.3) | | |
# | Section 7: Window Functions (7.1–7.4) | | |
# | Section 8: Dashboard Challenges (8.1–8.3) | | |
#
# ---
#
# ### GitHub
#
# | Item | Status | Notes |
# |------|--------|-------|
# | Exercises notebook committed and pushed | | |
# | Lab notebook committed and pushed | | |
#
# ---
#
# **Blockers — anything preventing a ✓?**

# %% [markdown]
# *Double-click here and describe any blockers.*

# %% [markdown]
# ---
#
# ## Part 3: Engineering Reading Club
#
# ### This Week's Article
#
# **Things I Wished More Developers Knew About Databases**
# *Jaana Dogan (rakyll)*
#
# Search for this article by title — it is widely available and has been republished on several platforms. The original was published on Medium.
#
# Topics covered: indexes, transactions, N+1 queries, connection pools, query optimisation, and more. Reading time: ~20 minutes.
#
# **Why this article?** It is written for engineers, not DBAs. Every data engineer will eventually encounter performance problems caused by missing indexes or poorly structured queries. This article gives you the vocabulary to recognise and fix them.
#
# ---
#
# ### Before You Read
#
# **Q: The article title implies developers often do not know enough about databases. Based on Week 2, what is one thing you now understand about databases that you did not know before this week?**

# %% [markdown]
# *Your answer before reading:*

# %% [markdown]
# **Q: What do you predict will be the most surprising point in the article?**

# %% [markdown]
# *Your prediction:*

# %% [markdown]
# ---
#
# ### After You Read — Discussion Prompts
#
# 1. The article discusses indexes in detail. After reading it alongside Lesson 4, has your mental model of how indexes work changed? What specifically is now clearer?
#
# 2. The author mentions connection pools and N+1 queries — topics you have not covered yet. What did you understand about them from context? What questions do they raise?
#
# 3. The author says knowing SQL well is not the same as knowing databases well. Do you agree? What is the gap between the two?
#
# 4. Which point in the article is most directly relevant to the work of a data engineer (as opposed to an application developer)?
#
# 5. The article is from a developer's perspective. Is there anything it says that you would do differently in a data engineering context?

# %% [markdown]
# ---
#
# ## Part 4: 5-Minute Summary
#
# **What surprised me most:**

# %% [markdown]
# *Double-click here and write what genuinely surprised you about the article. Not what was interesting — what caught you off guard.*

# %% [markdown]
# **Three key takeaways:**

# %% [markdown]
# 1. *First takeaway*
#
# 2. *Second takeaway*
#
# 3. *Third takeaway*

# %% [markdown]
# **One question I still have:**

# %% [markdown]
# *Double-click here and write your question.*

# %% [markdown]
# ---
#
# ## Part 5: Engineering Growth Plan — Week 2 Check-in
#
# Open your growth plan: [../activities/engineering_growth_plan.ipynb](../week1/activities/engineering_growth_plan.ipynb)
#
# *(Week 1 / activities / engineering_growth_plan.ipynb)*
#
# **Review and answer these questions here before updating the plan:**
#
# **Which skills from your Week 1 self-assessment moved up this week?**

# %% [markdown]
# *e.g. 'SQL moved from a 2 to a 3 — I can now write JOINs and GROUP BY without looking at the syntax.'*

# %% [markdown]
# **What was harder than expected this week?**

# %% [markdown]
# *Be specific — not 'SQL was hard' but which concept specifically was harder than expected and why.*

# %% [markdown]
# **Commit when done:**
#
# ```
# git add week2/
# git commit -m 'Complete Week 2 activities'
# git push
# ```
